# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-90.000,high=90.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 775

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" +weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dsc=city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Dsc": city_weather_dsc})       
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | escanaba
# Processing Record 2 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 1 | taby
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | jumla
# Processing Record 6 of Set 1 | hambantota
# Processing Record 7 of Set 1 | bathsheba
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | malaryta
# Processing Record 10 of Set 1 | nouakchott
# Processing Record 11 of Set 1 | camacupa
# Processing Record 12 of Set 1 | norrtalje
# Processing Record 13 of Set 1 | sao filipe
# Processing Record 14 of Set 1 | saldanha
# Processing Record 15 of Set 1 | raudeberg
# Processing Record 16 of Set 1 | lebedyn
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | los llanos de aridane
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | urucara
# Processing Record 21 of Set 1 | milyutinskaya
# Processing Record 22 of Set 1 | arklow
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | omboue
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | suez
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | bari
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | sambava
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | kirkland lake
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | borlange
# City not found. Skipping...
# Processing Record 37 of Set 1 | adeje
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | vietri sul mare
# Processing Record 40 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 1 | lelesti
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 1 | lakselv
# Processing Record 45 of Set 1 | qom
# Processing Record 46 of Set 1 | inhambane
# Processing Record 47 of Set 1 | praia da vitoria
# Processing Record 48 of Set 1 | hire
# City not found. Skipping...
# Processing Record 49 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | ashdod
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | salalah
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | segezha
# Processing Record 9 of Set 2 | burgeo
# Processing Record 10 of Set 2 | sable-sur-sarthe
# Processing Record 11 of Set 2 | lima duarte
# Processing Record 12 of Set 2 | molochnoye
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | saint-augustin
# Processing Record 15 of Set 2 | port-gentil
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | chanika
# Processing Record 18 of Set 2 | porto novo
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | tokzar
# City not found. Skipping...
# Processing Record 21 of Set 2 | gunupur
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 2 | pangnirtung
# Processing Record 26 of Set 2 | tambul
# City not found. Skipping...
# Processing Record 27 of Set 2 | urubicha
# Processing Record 28 of Set 2 | borovoy
# Processing Record 29 of Set 2 | kirishi
# Processing Record 30 of Set 2 | a
# City not found. Skipping...
# Processing Record 31 of Set 2 | bosaso
# Processing Record 32 of Set 2 | tessaoua
# Processing Record 33 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | imeni babushkina
# Processing Record 36 of Set 2 | mopti
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | amarante do maranhao
# Processing Record 39 of Set 2 | harindanga
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | garmsar
# Processing Record 42 of Set 2 | amalapuram
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | ambanja
# Processing Record 45 of Set 2 | necochea
# Processing Record 46 of Set 2 | qandala
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | gamboula
# Processing Record 49 of Set 2 | novoagansk
# Processing Record 50 of Set 2 | nova esperanca
# Processing Record 1 of Set 3 | wenchi
# Processing Record 2 of Set 3 | angra dos reis
# Processing Record 3 of Set 3 | chuy
# Processing Record 4 of Set 3 | coari
# Processing Record 5 of Set 3 | marienburg
# Processing Record 6 of Set 3 | codrington
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | ouargaye
# Processing Record 11 of Set 3 | ostrovnoy
# Processing Record 12 of Set 3 | canalete
# Processing Record 13 of Set 3 | clyde river
# Processing Record 14 of Set 3 | brae
# Processing Record 15 of Set 3 | cape elizabeth
# City not found. Skipping...
# Processing Record 16 of Set 3 | dzilam gonzalez
# Processing Record 17 of Set 3 | hamilton
# Processing Record 18 of Set 3 | namibe
# Processing Record 19 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 20 of Set 3 | cap malheureux
# Processing Record 21 of Set 3 | karasuk
# Processing Record 22 of Set 3 | newport
# Processing Record 23 of Set 3 | ugoofaaru
# Processing Record 24 of Set 3 | aswan
# Processing Record 25 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 26 of Set 3 | blagoyevo
# Processing Record 27 of Set 3 | sayyan
# Processing Record 28 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 3 | soyo
# Processing Record 30 of Set 3 | castrillon
# Processing Record 31 of Set 3 | sirjan
# Processing Record 32 of Set 3 | mezen
# Processing Record 33 of Set 3 | tabriz
# Processing Record 34 of Set 3 | pital
# Processing Record 35 of Set 3 | nioro
# Processing Record 36 of Set 3 | eyl
# Processing Record 37 of Set 3 | gerash
# Processing Record 38 of Set 3 | kifri
# Processing Record 39 of Set 3 | tabou
# Processing Record 40 of Set 3 | belmonte
# Processing Record 41 of Set 3 | montepuez
# Processing Record 42 of Set 3 | natal
# Processing Record 43 of Set 3 | ronne
# Processing Record 44 of Set 3 | ponta do sol
# Processing Record 45 of Set 3 | halden
# Processing Record 46 of Set 3 | cabedelo
# Processing Record 47 of Set 3 | sao geraldo do araguaia
# Processing Record 48 of Set 3 | kholm-zhirkovskiy
# Processing Record 49 of Set 3 | obigarm
# Processing Record 50 of Set 3 | mayahi
# Processing Record 1 of Set 4 | korla
# Processing Record 2 of Set 4 | saint-pierre
# Processing Record 3 of Set 4 | kismayo
# Processing Record 4 of Set 4 | ponta delgada
# Processing Record 5 of Set 4 | cayenne
# Processing Record 6 of Set 4 | akdepe
# Processing Record 7 of Set 4 | coihaique
# Processing Record 8 of Set 4 | havoysund
# Processing Record 9 of Set 4 | gopalpur
# Processing Record 10 of Set 4 | carballo
# Processing Record 11 of Set 4 | nanortalik
# Processing Record 12 of Set 4 | sao joao da barra
# Processing Record 13 of Set 4 | grindavik
# Processing Record 14 of Set 4 | portoferraio
# Processing Record 15 of Set 4 | jalu
# Processing Record 16 of Set 4 | szentkiraly
# Processing Record 17 of Set 4 | boa vista
# Processing Record 18 of Set 4 | luderitz
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | quatre cocos
# Processing Record 21 of Set 4 | epe
# Processing Record 22 of Set 4 | manali
# Processing Record 23 of Set 4 | paamiut
# Processing Record 24 of Set 4 | kafue
# Processing Record 25 of Set 4 | les cayes
# Processing Record 26 of Set 4 | phalaborwa
# Processing Record 27 of Set 4 | vardo
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | santa cruz de tenerife
# Processing Record 30 of Set 4 | williamsburg
# Processing Record 31 of Set 4 | alexandru odobescu
# Processing Record 32 of Set 4 | visnes
# Processing Record 33 of Set 4 | lebu
# Processing Record 34 of Set 4 | requena
# Processing Record 35 of Set 4 | chapais
# Processing Record 36 of Set 4 | golden rock
# City not found. Skipping...
# Processing Record 37 of Set 4 | springdale
# Processing Record 38 of Set 4 | togul
# Processing Record 39 of Set 4 | casma
# Processing Record 40 of Set 4 | turukhansk
# Processing Record 41 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 4 | narsaq
# Processing Record 43 of Set 4 | os
# City not found. Skipping...
# Processing Record 44 of Set 4 | alcains
# Processing Record 45 of Set 4 | maralal
# Processing Record 46 of Set 4 | ladario
# Processing Record 47 of Set 4 | cervo
# Processing Record 48 of Set 4 | belyy yar
# Processing Record 49 of Set 4 | kachiry
# Processing Record 50 of Set 4 | kaina
# Processing Record 1 of Set 5 | miranda
# Processing Record 2 of Set 5 | ormara
# Processing Record 3 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 5 | oranjemund
# Processing Record 5 of Set 5 | maniitsoq
# Processing Record 6 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 5 | victoria
# Processing Record 8 of Set 5 | pervomayskoye
# Processing Record 9 of Set 5 | amberieu-en-bugey
# Processing Record 10 of Set 5 | adrar
# Processing Record 11 of Set 5 | lagos
# Processing Record 12 of Set 5 | matiri
# Processing Record 13 of Set 5 | asmar
# Processing Record 14 of Set 5 | vila franca do campo
# Processing Record 15 of Set 5 | itarema
# Processing Record 16 of Set 5 | bodden town
# Processing Record 17 of Set 5 | talavera de la reina
# Processing Record 18 of Set 5 | benguela
# Processing Record 19 of Set 5 | wlodawa
# Processing Record 20 of Set 5 | husavik
# Processing Record 21 of Set 5 | sisimiut
# Processing Record 22 of Set 5 | gumushane
# City not found. Skipping...
# Processing Record 23 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 5 | sovetskiy
# Processing Record 25 of Set 5 | gat
# Processing Record 26 of Set 5 | hualmay
# Processing Record 27 of Set 5 | quartucciu
# Processing Record 28 of Set 5 | bandarbeyla
# Processing Record 29 of Set 5 | okitipupa
# Processing Record 30 of Set 5 | marsa matruh
# Processing Record 31 of Set 5 | talnakh
# Processing Record 32 of Set 5 | fagernes
# Processing Record 33 of Set 5 | estreito
# Processing Record 34 of Set 5 | kikwit
# Processing Record 35 of Set 5 | turayf
# Processing Record 36 of Set 5 | diego de almagro
# Processing Record 37 of Set 5 | rabak
# Processing Record 38 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 5 | rundu
# Processing Record 41 of Set 5 | edgewater
# Processing Record 42 of Set 5 | dikson
# Processing Record 43 of Set 5 | taoudenni
# Processing Record 44 of Set 5 | ocean springs
# Processing Record 45 of Set 5 | lelystad
# Processing Record 46 of Set 5 | jega
# Processing Record 47 of Set 5 | camargo
# Processing Record 48 of Set 5 | comandau
# Processing Record 49 of Set 5 | talwara
# Processing Record 50 of Set 5 | teguldet
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | puerto el triunfo
# Processing Record 3 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 6 | kolondieba
# Processing Record 5 of Set 6 | matara
# Processing Record 6 of Set 6 | buenos aires
# Processing Record 7 of Set 6 | conceicao do araguaia
# Processing Record 8 of Set 6 | gibara
# Processing Record 9 of Set 6 | magaria
# Processing Record 10 of Set 6 | malpe
# Processing Record 11 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 6 | kostomuksha
# Processing Record 13 of Set 6 | afgoye
# City not found. Skipping...
# Processing Record 14 of Set 6 | silvan
# Processing Record 15 of Set 6 | nailsea
# Processing Record 16 of Set 6 | teguise
# Processing Record 17 of Set 6 | limenaria
# Processing Record 18 of Set 6 | valparaiso
# Processing Record 19 of Set 6 | manta
# Processing Record 20 of Set 6 | la palma
# Processing Record 21 of Set 6 | puerto triunfo
# Processing Record 22 of Set 6 | itupiranga
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | fethiye
# Processing Record 25 of Set 6 | oranzherei
# Processing Record 26 of Set 6 | kissidougou
# Processing Record 27 of Set 6 | hopelchen
# Processing Record 28 of Set 6 | harper
# Processing Record 29 of Set 6 | cockburn town
# Processing Record 30 of Set 6 | sorland
# Processing Record 31 of Set 6 | constitucion
# Processing Record 32 of Set 6 | coro
# Processing Record 33 of Set 6 | alice town
# Processing Record 34 of Set 6 | carutapera
# Processing Record 35 of Set 6 | marawi
# Processing Record 36 of Set 6 | kalmunai
# Processing Record 37 of Set 6 | shakawe
# Processing Record 38 of Set 6 | marrakesh
# Processing Record 39 of Set 6 | mahon
# Processing Record 40 of Set 6 | coquimbo
# Processing Record 41 of Set 6 | mpophomeni
# Processing Record 42 of Set 6 | ust-kulom
# Processing Record 43 of Set 6 | parfenyevo
# Processing Record 44 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 6 | vestmannaeyjar
# Processing Record 46 of Set 6 | nassau
# Processing Record 47 of Set 6 | beloha
# Processing Record 48 of Set 6 | antalaha
# Processing Record 49 of Set 6 | rabo de peixe
# Processing Record 50 of Set 6 | tessalit
# Processing Record 1 of Set 7 | irbit
# Processing Record 2 of Set 7 | ode
# Processing Record 3 of Set 7 | faya
# Processing Record 4 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 7 | baie-saint-paul
# Processing Record 6 of Set 7 | presidencia roque saenz pena
# Processing Record 7 of Set 7 | presidente epitacio
# Processing Record 8 of Set 7 | novomykolayivka
# Processing Record 9 of Set 7 | houma
# Processing Record 10 of Set 7 | saint george
# Processing Record 11 of Set 7 | paita
# Processing Record 12 of Set 7 | jaguariaiva
# Processing Record 13 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 7 | zaysan
# Processing Record 15 of Set 7 | tatawin
# Processing Record 16 of Set 7 | zafra
# Processing Record 17 of Set 7 | richards bay
# Processing Record 18 of Set 7 | alexander city
# Processing Record 19 of Set 7 | juazeiro
# Processing Record 20 of Set 7 | sungurlare
# Processing Record 21 of Set 7 | viedma
# Processing Record 22 of Set 7 | touros
# Processing Record 23 of Set 7 | antofagasta
# Processing Record 24 of Set 7 | saint-joseph
# Processing Record 25 of Set 7 | sistranda
# Processing Record 26 of Set 7 | pointe-noire
# Processing Record 27 of Set 7 | gamba
# Processing Record 28 of Set 7 | havre-saint-pierre
# Processing Record 29 of Set 7 | asyut
# Processing Record 30 of Set 7 | borba
# Processing Record 31 of Set 7 | almaty
# Processing Record 32 of Set 7 | betanzos
# Processing Record 33 of Set 7 | thunder bay
# Processing Record 34 of Set 7 | san ramon
# Processing Record 35 of Set 7 | umm lajj
# Processing Record 36 of Set 7 | huarmey
# Processing Record 37 of Set 7 | kidal
# Processing Record 38 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 39 of Set 7 | kewanee
# Processing Record 40 of Set 7 | channel-port aux basques
# Processing Record 41 of Set 7 | acari
# Processing Record 42 of Set 7 | khalkhal
# Processing Record 43 of Set 7 | barcelos
# Processing Record 44 of Set 7 | andros town
# Processing Record 45 of Set 7 | gari
# Processing Record 46 of Set 7 | yar-sale
# Processing Record 47 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 48 of Set 7 | hammerfest
# Processing Record 49 of Set 7 | bafata
# Processing Record 50 of Set 7 | kadnikov
# Processing Record 1 of Set 8 | castro
# Processing Record 2 of Set 8 | pervomayskiy
# Processing Record 3 of Set 8 | strezhevoy
# Processing Record 4 of Set 8 | ferrol
# Processing Record 5 of Set 8 | the valley
# Processing Record 6 of Set 8 | le port
# Processing Record 7 of Set 8 | tyup
# Processing Record 8 of Set 8 | zabol
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | qasigiannguit
# Processing Record 11 of Set 8 | krasnoselkup
# Processing Record 12 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 8 | akdagmadeni
# Processing Record 14 of Set 8 | hobyo
# Processing Record 15 of Set 8 | calvinia
# Processing Record 16 of Set 8 | giyani
# Processing Record 17 of Set 8 | aksarka
# Processing Record 18 of Set 8 | barvinkove
# Processing Record 19 of Set 8 | kidodi
# Processing Record 20 of Set 8 | pelym
# Processing Record 21 of Set 8 | nantucket
# Processing Record 22 of Set 8 | palatka
# Processing Record 23 of Set 8 | danielskuil
# Processing Record 24 of Set 8 | shubarkuduk
# Processing Record 25 of Set 8 | riyadh
# Processing Record 26 of Set 8 | naral
# City not found. Skipping...
# Processing Record 27 of Set 8 | kharian
# Processing Record 28 of Set 8 | angoche
# Processing Record 29 of Set 8 | diamantino
# Processing Record 30 of Set 8 | segou
# Processing Record 31 of Set 8 | nueva gerona
# Processing Record 32 of Set 8 | columbia
# Processing Record 33 of Set 8 | tocopilla
# Processing Record 34 of Set 8 | bainbridge
# Processing Record 35 of Set 8 | ellisras
# Processing Record 36 of Set 8 | caravelas
# Processing Record 37 of Set 8 | rawson
# Processing Record 38 of Set 8 | cordoba
# Processing Record 39 of Set 8 | saint anthony
# Processing Record 40 of Set 8 | puerto ayora
# Processing Record 41 of Set 8 | nkwerre
# Processing Record 42 of Set 8 | mehamn
# Processing Record 43 of Set 8 | dabhol
# Processing Record 44 of Set 8 | boende
# Processing Record 45 of Set 8 | luwero
# Processing Record 46 of Set 8 | bardstown
# Processing Record 47 of Set 8 | annau
# Processing Record 48 of Set 8 | upata
# Processing Record 49 of Set 8 | vossevangen
# Processing Record 50 of Set 8 | leningradskiy
# Processing Record 1 of Set 9 | opuwo
# Processing Record 2 of Set 9 | ancud
# Processing Record 3 of Set 9 | ortakoy
# Processing Record 4 of Set 9 | marzuq
# Processing Record 5 of Set 9 | vipperod
# Processing Record 6 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 9 | santa marta
# Processing Record 8 of Set 9 | rognan
# Processing Record 9 of Set 9 | skjervoy
# Processing Record 10 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 11 of Set 9 | moita bonita
# Processing Record 12 of Set 9 | yasnyy
# Processing Record 13 of Set 9 | banswara
# Processing Record 14 of Set 9 | marapanim
# Processing Record 15 of Set 9 | gazanjyk
# Processing Record 16 of Set 9 | evinayong
# Processing Record 17 of Set 9 | mchinji
# Processing Record 18 of Set 9 | baoro
# Processing Record 19 of Set 9 | ostersund
# Processing Record 20 of Set 9 | totness
# Processing Record 21 of Set 9 | kattivakkam
# Processing Record 22 of Set 9 | makat
# Processing Record 23 of Set 9 | puerto carreno
# Processing Record 24 of Set 9 | nuuk
# Processing Record 25 of Set 9 | abu dhabi
# Processing Record 26 of Set 9 | talara
# Processing Record 27 of Set 9 | el faiyum
# City not found. Skipping...
# Processing Record 28 of Set 9 | araouane
# Processing Record 29 of Set 9 | barsovo
# Processing Record 30 of Set 9 | kavaratti
# Processing Record 31 of Set 9 | inongo
# Processing Record 32 of Set 9 | reinosa
# Processing Record 33 of Set 9 | gornyak
# Processing Record 34 of Set 9 | taltal
# Processing Record 35 of Set 9 | vallenar
# Processing Record 36 of Set 9 | llanes
# Processing Record 37 of Set 9 | castelo do piaui
# Processing Record 38 of Set 9 | caernarfon
# Processing Record 39 of Set 9 | melipilla
# Processing Record 40 of Set 9 | goderich
# Processing Record 41 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 9 | derbent
# Processing Record 43 of Set 9 | salinas
# Processing Record 44 of Set 9 | dingle
# Processing Record 45 of Set 9 | chik
# Processing Record 46 of Set 9 | polunochnoye
# Processing Record 47 of Set 9 | dwarka
# Processing Record 48 of Set 9 | kondinskoye
# Processing Record 49 of Set 9 | tignere
# Processing Record 50 of Set 9 | togur
# Processing Record 1 of Set 10 | azare
# Processing Record 2 of Set 10 | sao miguel do araguaia
# Processing Record 3 of Set 10 | georgiyevka
# Processing Record 4 of Set 10 | las matas de farfan
# Processing Record 5 of Set 10 | svetlogorsk
# Processing Record 6 of Set 10 | virginia beach
# Processing Record 7 of Set 10 | vila velha
# Processing Record 8 of Set 10 | muscat
# Processing Record 9 of Set 10 | burica
# City not found. Skipping...
# Processing Record 10 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 11 of Set 10 | ginir
# Processing Record 12 of Set 10 | ibra
# Processing Record 13 of Set 10 | krasnaya gorbatka
# Processing Record 14 of Set 10 | abu samrah
# Processing Record 15 of Set 10 | maine-soroa
# Processing Record 16 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 10 | coral springs
# Processing Record 18 of Set 10 | camden
# Processing Record 19 of Set 10 | limoux
# Processing Record 20 of Set 10 | san cristobal
# Processing Record 21 of Set 10 | henties bay
# Processing Record 22 of Set 10 | saint-francois
# Processing Record 23 of Set 10 | lucapa
# Processing Record 24 of Set 10 | verkhnyaya inta
# Processing Record 25 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 26 of Set 10 | ushtobe
# Processing Record 27 of Set 10 | micheweni
# Processing Record 28 of Set 10 | nekrasovskoye
# Processing Record 29 of Set 10 | gilazi
# City not found. Skipping...
# Processing Record 30 of Set 10 | anuppur
# Processing Record 31 of Set 10 | sao lourenco do sul
# Processing Record 32 of Set 10 | annecy-le-vieux
# Processing Record 33 of Set 10 | bud
# Processing Record 34 of Set 10 | olavarria
# Processing Record 35 of Set 10 | bangassou
# Processing Record 36 of Set 10 | birin
# Processing Record 37 of Set 10 | tabas
# Processing Record 38 of Set 10 | parnarama
# Processing Record 39 of Set 10 | mistelbach
# Processing Record 40 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 41 of Set 10 | ionia
# Processing Record 42 of Set 10 | urfa
# City not found. Skipping...
# Processing Record 43 of Set 10 | shelburne
# Processing Record 44 of Set 10 | margate
# Processing Record 45 of Set 10 | huesca
# Processing Record 46 of Set 10 | puerto narino
# Processing Record 47 of Set 10 | lafiagi
# Processing Record 48 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 10 | kilembe
# Processing Record 50 of Set 10 | darnah
# Processing Record 1 of Set 11 | oktyabrskiy
# Processing Record 2 of Set 11 | bjornevatn
# Processing Record 3 of Set 11 | birjand
# Processing Record 4 of Set 11 | grand-santi
# Processing Record 5 of Set 11 | mantua
# Processing Record 6 of Set 11 | benevento
# Processing Record 7 of Set 11 | verkhniy ufaley
# Processing Record 8 of Set 11 | lasa
# Processing Record 9 of Set 11 | romilly-sur-seine
# Processing Record 10 of Set 11 | sidi ali
# Processing Record 11 of Set 11 | kamenka
# Processing Record 12 of Set 11 | kasane
# Processing Record 13 of Set 11 | leh
# Processing Record 14 of Set 11 | kasangulu
# Processing Record 15 of Set 11 | kutum
# Processing Record 16 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 17 of Set 11 | ploemeur
# Processing Record 18 of Set 11 | junin
# Processing Record 19 of Set 11 | muros
# Processing Record 20 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 21 of Set 11 | tome
# Processing Record 22 of Set 11 | svetlyy
# Processing Record 23 of Set 11 | helsinki
# Processing Record 24 of Set 11 | pisco
# Processing Record 25 of Set 11 | tarauaca
# Processing Record 26 of Set 11 | derzhavinsk
# Processing Record 27 of Set 11 | honavar
# Processing Record 28 of Set 11 | iralaya
# Processing Record 29 of Set 11 | duartina
# Processing Record 30 of Set 11 | atar
# Processing Record 31 of Set 11 | northampton
# Processing Record 32 of Set 11 | cap-aux-meules
# Processing Record 33 of Set 11 | umm jarr
# City not found. Skipping...
# Processing Record 34 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 35 of Set 11 | khorixas
# Processing Record 36 of Set 11 | oksfjord
# Processing Record 37 of Set 11 | entre rios
# Processing Record 38 of Set 11 | berlevag
# Processing Record 39 of Set 11 | sept-iles
# Processing Record 40 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 41 of Set 11 | seguela
# Processing Record 42 of Set 11 | sal rei
# Processing Record 43 of Set 11 | llandrindod wells
# Processing Record 44 of Set 11 | merseburg
# Processing Record 45 of Set 11 | samana
# Processing Record 46 of Set 11 | kajaani
# Processing Record 47 of Set 11 | tamandare
# Processing Record 48 of Set 11 | dakoro
# Processing Record 49 of Set 11 | chachapoyas
# Processing Record 50 of Set 11 | la union
# Processing Record 1 of Set 12 | lynn
# Processing Record 2 of Set 12 | saint-georges
# Processing Record 3 of Set 12 | beira
# Processing Record 4 of Set 12 | kofarnihon
# City not found. Skipping...
# Processing Record 5 of Set 12 | makaryev
# Processing Record 6 of Set 12 | cullman
# Processing Record 7 of Set 12 | male
# Processing Record 8 of Set 12 | ramgarh
# Processing Record 9 of Set 12 | atasu
# Processing Record 10 of Set 12 | adet
# Processing Record 11 of Set 12 | meaux
# Processing Record 12 of Set 12 | roquetas de mar
# Processing Record 13 of Set 12 | marsh harbour
# Processing Record 14 of Set 12 | mayumba
# Processing Record 15 of Set 12 | canutama
# Processing Record 16 of Set 12 | khotyn
# Processing Record 17 of Set 12 | port-cartier
# Processing Record 18 of Set 12 | abha
# Processing Record 19 of Set 12 | pascagoula
# Processing Record 20 of Set 12 | tutoia
# Processing Record 21 of Set 12 | turkistan
# Processing Record 22 of Set 12 | lobau
# Processing Record 23 of Set 12 | yartsevo
# Processing Record 24 of Set 12 | callaway
# Processing Record 25 of Set 12 | ylojarvi
# Processing Record 26 of Set 12 | acarau
# Processing Record 27 of Set 12 | chicama
# Processing Record 28 of Set 12 | zanjan
# Processing Record 29 of Set 12 | sur
# Processing Record 30 of Set 12 | bubaque
# Processing Record 31 of Set 12 | iquitos
# Processing Record 32 of Set 12 | isoka
# Processing Record 33 of Set 12 | felanitx
# Processing Record 34 of Set 12 | kem
# Processing Record 35 of Set 12 | lima
# Processing Record 36 of Set 12 | qaqortoq
# Processing Record 37 of Set 12 | curuca
# Processing Record 38 of Set 12 | gboko
# Processing Record 39 of Set 12 | shcholkine
# City not found. Skipping...
# Processing Record 40 of Set 12 | westport
# Processing Record 41 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 42 of Set 12 | igrim
# Processing Record 43 of Set 12 | abu zabad
# Processing Record 44 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 45 of Set 12 | birao
# Processing Record 46 of Set 12 | dudinka
# Processing Record 47 of Set 12 | bull savanna
# Processing Record 48 of Set 12 | matay
# Processing Record 49 of Set 12 | mitu
# Processing Record 50 of Set 12 | kjollefjord
# Processing Record 1 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 2 of Set 13 | bonavista
# Processing Record 3 of Set 13 | rauma
# Processing Record 4 of Set 13 | karpathos
# Processing Record 5 of Set 13 | siderno
# Processing Record 6 of Set 13 | witu
# Processing Record 7 of Set 13 | staunton
# Processing Record 8 of Set 13 | nioki
# Processing Record 9 of Set 13 | vitina
# Processing Record 10 of Set 13 | trinidad
# Processing Record 11 of Set 13 | zyryanskoye
# Processing Record 12 of Set 13 | putina
# Processing Record 13 of Set 13 | sorkjosen
# Processing Record 14 of Set 13 | mollendo
# Processing Record 15 of Set 13 | oktyabrskoye
# Processing Record 16 of Set 13 | george
# Processing Record 17 of Set 13 | rayevskiy
# Processing Record 18 of Set 13 | huescar
# Processing Record 19 of Set 13 | pontes e lacerda
# Processing Record 20 of Set 13 | ifanadiana
# Processing Record 21 of Set 13 | tyumentsevo
# Processing Record 22 of Set 13 | rio de janeiro
# Processing Record 23 of Set 13 | wad rawah
# Processing Record 24 of Set 13 | gravdal
# Processing Record 25 of Set 13 | sao felix do xingu
# Processing Record 26 of Set 13 | walvis bay
# Processing Record 27 of Set 13 | coxim
# Processing Record 28 of Set 13 | grand gaube
# Processing Record 29 of Set 13 | quchan
# Processing Record 30 of Set 13 | haileybury
# Processing Record 31 of Set 13 | nuevo celilac
# City not found. Skipping...
# Processing Record 32 of Set 13 | qobustan
# Processing Record 33 of Set 13 | bedi
# Processing Record 34 of Set 13 | villazon
# Processing Record 35 of Set 13 | pangody
# Processing Record 36 of Set 13 | pula
# Processing Record 37 of Set 13 | rio cuarto
# Processing Record 38 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 39 of Set 13 | zhetybay
# City not found. Skipping...
# Processing Record 40 of Set 13 | yangambi
# Processing Record 41 of Set 13 | malpura
# Processing Record 42 of Set 13 | saint-louis
# Processing Record 43 of Set 13 | hofn
# Processing Record 44 of Set 13 | batsfjord
# Processing Record 45 of Set 13 | puerto del rosario
# Processing Record 46 of Set 13 | mangai
# Processing Record 47 of Set 13 | idlib
# Processing Record 48 of Set 13 | vyartsilya
# Processing Record 49 of Set 13 | shetpe
# Processing Record 50 of Set 13 | amposta
# Processing Record 1 of Set 14 | kayerkan
# Processing Record 2 of Set 14 | ericeira
# Processing Record 3 of Set 14 | buerarema
# Processing Record 4 of Set 14 | balakirevo
# Processing Record 5 of Set 14 | keita
# Processing Record 6 of Set 14 | geilo
# Processing Record 7 of Set 14 | hit
# Processing Record 8 of Set 14 | nalut
# Processing Record 9 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 10 of Set 14 | kathmandu
# Processing Record 11 of Set 14 | manaure
# Processing Record 12 of Set 14 | bolshaya martynovka
# Processing Record 13 of Set 14 | waddan
# Processing Record 14 of Set 14 | zhezkazgan
# Processing Record 15 of Set 14 | nyagan
# Processing Record 16 of Set 14 | reconquista
# Processing Record 17 of Set 14 | nizhnevartovsk
# Processing Record 18 of Set 14 | trairi
# Processing Record 19 of Set 14 | vaijapur
# Processing Record 20 of Set 14 | kuminskiy
# Processing Record 21 of Set 14 | lypova dolyna
# Processing Record 22 of Set 14 | hirekerur
# Processing Record 23 of Set 14 | stornoway
# Processing Record 24 of Set 14 | plettenberg bay
# Processing Record 25 of Set 14 | povenets
# Processing Record 26 of Set 14 | tiznit
# Processing Record 27 of Set 14 | iracoubo
# Processing Record 28 of Set 14 | inirida
# Processing Record 29 of Set 14 | kuito
# Processing Record 30 of Set 14 | ureki
# Processing Record 31 of Set 14 | kautokeino
# Processing Record 32 of Set 14 | kazerun
# Processing Record 33 of Set 14 | misratah
# Processing Record 34 of Set 14 | zudilovo
# Processing Record 35 of Set 14 | lardos
# Processing Record 36 of Set 14 | vlore
# Processing Record 37 of Set 14 | tazovskiy
# Processing Record 38 of Set 14 | livingstone
# Processing Record 39 of Set 14 | anori
# Processing Record 40 of Set 14 | conde
# Processing Record 41 of Set 14 | san luis
# Processing Record 42 of Set 14 | turbat
# Processing Record 43 of Set 14 | bobosevo
# City not found. Skipping...
# Processing Record 44 of Set 14 | elizabeth city
# Processing Record 45 of Set 14 | wilmington
# Processing Record 46 of Set 14 | gornopravdinsk
# Processing Record 47 of Set 14 | maldonado
# Processing Record 48 of Set 14 | jacmel
# Processing Record 49 of Set 14 | yining
# Processing Record 50 of Set 14 | bafra
# Processing Record 1 of Set 15 | lagoa
# Processing Record 2 of Set 15 | san juan
# Processing Record 3 of Set 15 | zlynka
# Processing Record 4 of Set 15 | dibulla
# Processing Record 5 of Set 15 | arlit
# Processing Record 6 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 15 | vyazma
# Processing Record 8 of Set 15 | sant julia de loria
# Processing Record 9 of Set 15 | rio gallegos
# Processing Record 10 of Set 15 | warmbad
# Processing Record 11 of Set 15 | itaituba
# Processing Record 12 of Set 15 | locri
# Processing Record 13 of Set 15 | port blair
# Processing Record 14 of Set 15 | kande
# Processing Record 15 of Set 15 | san joaquin
# Processing Record 16 of Set 15 | ranipur
# Processing Record 17 of Set 15 | lar
# Processing Record 18 of Set 15 | gandu
# Processing Record 19 of Set 15 | sovetsk
# Processing Record 20 of Set 15 | kinshasa
# Processing Record 21 of Set 15 | niksar
# Processing Record 22 of Set 15 | bardiyah
# Processing Record 23 of Set 15 | sandane
# Processing Record 24 of Set 15 | ithaca
# Processing Record 25 of Set 15 | benghazi
# Processing Record 26 of Set 15 | vicosa
# Processing Record 27 of Set 15 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 28 of Set 15 | mazamari
# Processing Record 29 of Set 15 | dustlik
# Processing Record 30 of Set 15 | dzaoudzi
# Processing Record 31 of Set 15 | khor
# Processing Record 32 of Set 15 | molnlycke
# Processing Record 33 of Set 15 | kyzyl-suu
# Processing Record 34 of Set 15 | siniscola
# Processing Record 35 of Set 15 | doboz
# Processing Record 36 of Set 15 | santa maria
# Processing Record 37 of Set 15 | zdunska wola
# Processing Record 38 of Set 15 | santa comba
# Processing Record 39 of Set 15 | okandja
# City not found. Skipping...
# Processing Record 40 of Set 15 | vuktyl
# Processing Record 41 of Set 15 | joshimath
# Processing Record 42 of Set 15 | ribas do rio pardo
# Processing Record 43 of Set 15 | la rochelle
# Processing Record 44 of Set 15 | uthal
# Processing Record 45 of Set 15 | padang
# Processing Record 46 of Set 15 | kokkola
# Processing Record 47 of Set 15 | marquette
# Processing Record 48 of Set 15 | miquelon
# Processing Record 49 of Set 15 | klyuchi
# Processing Record 50 of Set 15 | gorele
# Processing Record 1 of Set 16 | danville
# Processing Record 2 of Set 16 | shar
# Processing Record 3 of Set 16 | kaoma
# Processing Record 4 of Set 16 | kottagudem
# Processing Record 5 of Set 16 | fereydunshahr
# Processing Record 6 of Set 16 | praia
# Processing Record 7 of Set 16 | laguna
# Processing Record 8 of Set 16 | bage
# Processing Record 9 of Set 16 | nushki
# Processing Record 10 of Set 16 | ukhta
# Processing Record 11 of Set 16 | toktogul
# Processing Record 12 of Set 16 | ayabaca
# Processing Record 13 of Set 16 | vokhtoga
# Processing Record 14 of Set 16 | kargil
# Processing Record 15 of Set 16 | camacha
# Processing Record 16 of Set 16 | sakakah
# Processing Record 17 of Set 16 | deori
# Processing Record 18 of Set 16 | banyo
# Processing Record 19 of Set 16 | shahr-e kord
# Processing Record 20 of Set 16 | kholm
# Processing Record 21 of Set 16 | miranorte
# City not found. Skipping...
# Processing Record 22 of Set 16 | sao francisco do sul
# Processing Record 23 of Set 16 | rosoman
# Processing Record 24 of Set 16 | mizdah
# Processing Record 25 of Set 16 | ndola
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 705

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Escanaba  45.7453  -87.0646     32.31        96         100        5.75
# 1        Taby  59.4439   18.0687     42.58        93         100        8.05
# 2     Ushuaia -54.8000  -68.3000     46.06        87           0        4.61
# 3       Jumla  29.2747   82.1838     51.89        47          93        2.10
# 4  Hambantota   6.1241   81.1185     77.34       100          75        1.14
# 5   Bathsheba  13.2167  -59.5167     79.41        89          75       27.63
# 6  Georgetown   5.4112  100.3354     80.53        93          20        3.44
# 7    Malaryta  51.7905   24.0740     39.61        93         100        5.44
# 8  Nouakchott  18.0858  -15.9785     73.33        60           0       12.77
# 9    Camacupa -12.0167   17.4833     60.53        94         100        1.25
#
#   Country      Weather Dsc
# 0      US             mist
# 1      SE  overcast clouds
# 2      AR        clear sky
# 3      NP  overcast clouds
# 4      LK    broken clouds
# 5      BB    broken clouds
# 6      MY       few clouds
# 7      BY  overcast clouds
# 8      MR        clear sky
# 9      AO       light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Dsc'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reorder_column_list=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Dsc"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[reorder_column_list]

# Display sample data
city_data_df.head()
# Out:
#          City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    Escanaba      US  45.7453 -87.0646     32.31        96         100
# 1        Taby      SE  59.4439  18.0687     42.58        93         100
# 2     Ushuaia      AR -54.8000 -68.3000     46.06        87           0
# 3       Jumla      NP  29.2747  82.1838     51.89        47          93
# 4  Hambantota      LK   6.1241  81.1185     77.34       100          75
#
#    Wind Speed      Weather Dsc
# 0        5.75             mist
# 1        8.05  overcast clouds
# 2        4.61        clear sky
# 3        2.10  overcast clouds
# 4        1.14    broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Weather Dsc     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_name="WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_name,index_label="City_ID")
