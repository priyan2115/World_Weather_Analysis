# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-90.000,high=90.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 740

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" +weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dsc=city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Dsc": city_weather_dsc})       
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | maragogi
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | zaozerne
# Processing Record 4 of Set 1 | turek
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | rafai
# Processing Record 8 of Set 1 | thinadhoo
# Processing Record 9 of Set 1 | jizan
# Processing Record 10 of Set 1 | ghanzi
# Processing Record 11 of Set 1 | karaman
# Processing Record 12 of Set 1 | nova olimpia
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | roald
# Processing Record 15 of Set 1 | general roca
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | ardakan
# Processing Record 19 of Set 1 | havre-saint-pierre
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | zapolyarnyy
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | oksfjord
# Processing Record 27 of Set 1 | cidreira
# Processing Record 28 of Set 1 | puri
# Processing Record 29 of Set 1 | albal
# Processing Record 30 of Set 1 | stilfontein
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | luderitz
# Processing Record 34 of Set 1 | santa vitoria do palmar
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | lasa
# Processing Record 37 of Set 1 | ginir
# Processing Record 38 of Set 1 | touros
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | ovre ardal
# Processing Record 42 of Set 1 | upata
# Processing Record 43 of Set 1 | narsaq
# Processing Record 44 of Set 1 | berlevag
# Processing Record 45 of Set 1 | ostrovnoy
# Processing Record 46 of Set 1 | hofn
# Processing Record 47 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 1 | brae
# Processing Record 49 of Set 1 | nuuk
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | souillac
# Processing Record 3 of Set 2 | salalah
# Processing Record 4 of Set 2 | bousso
# Processing Record 5 of Set 2 | menongue
# Processing Record 6 of Set 2 | nawa
# Processing Record 7 of Set 2 | visnes
# Processing Record 8 of Set 2 | korla
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | kavaratti
# Processing Record 13 of Set 2 | altay
# Processing Record 14 of Set 2 | adwa
# Processing Record 15 of Set 2 | kangaatsiaq
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | sturgeon falls
# Processing Record 19 of Set 2 | kutum
# Processing Record 20 of Set 2 | adrar
# Processing Record 21 of Set 2 | grindavik
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | gat
# Processing Record 24 of Set 2 | coquimbo
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | urucara
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | lanivtsi
# Processing Record 32 of Set 2 | walvis bay
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | yenagoa
# Processing Record 35 of Set 2 | mokobeng
# Processing Record 36 of Set 2 | pombia
# Processing Record 37 of Set 2 | neyshabur
# Processing Record 38 of Set 2 | sambava
# Processing Record 39 of Set 2 | oranjemund
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | saint-ambroise
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | rosetta
# Processing Record 44 of Set 2 | aripuana
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | san cristobal
# Processing Record 47 of Set 2 | maceio
# Processing Record 48 of Set 2 | marmaris
# Processing Record 49 of Set 2 | bosaso
# Processing Record 50 of Set 2 | kokkola
# Processing Record 1 of Set 3 | ladario
# Processing Record 2 of Set 3 | cururupu
# Processing Record 3 of Set 3 | lagos
# Processing Record 4 of Set 3 | westport
# Processing Record 5 of Set 3 | lodja
# Processing Record 6 of Set 3 | constitucion
# Processing Record 7 of Set 3 | stokmarknes
# Processing Record 8 of Set 3 | pisco
# Processing Record 9 of Set 3 | margate
# Processing Record 10 of Set 3 | tarauaca
# Processing Record 11 of Set 3 | isiro
# Processing Record 12 of Set 3 | solikamsk
# Processing Record 13 of Set 3 | vila velha
# Processing Record 14 of Set 3 | khudumelapye
# Processing Record 15 of Set 3 | oistins
# Processing Record 16 of Set 3 | vicar
# Processing Record 17 of Set 3 | sakakah
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | cap malheureux
# Processing Record 20 of Set 3 | ancud
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | feuchtwangen
# Processing Record 23 of Set 3 | nanortalik
# Processing Record 24 of Set 3 | aden
# Processing Record 25 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 26 of Set 3 | asmara
# Processing Record 27 of Set 3 | waddan
# Processing Record 28 of Set 3 | ostersund
# Processing Record 29 of Set 3 | riyadh
# Processing Record 30 of Set 3 | nicoya
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | hearst
# Processing Record 33 of Set 3 | charleston
# Processing Record 34 of Set 3 | pangnirtung
# Processing Record 35 of Set 3 | pishin
# Processing Record 36 of Set 3 | najran
# Processing Record 37 of Set 3 | gerash
# Processing Record 38 of Set 3 | mehamn
# Processing Record 39 of Set 3 | iskateley
# Processing Record 40 of Set 3 | ribeira grande
# Processing Record 41 of Set 3 | torbay
# Processing Record 42 of Set 3 | bandarbeyla
# Processing Record 43 of Set 3 | marica
# Processing Record 44 of Set 3 | umm kaddadah
# Processing Record 45 of Set 3 | havelock
# Processing Record 46 of Set 3 | argelia
# Processing Record 47 of Set 3 | suez
# Processing Record 48 of Set 3 | kudahuvadhoo
# Processing Record 49 of Set 3 | san bernardo
# Processing Record 50 of Set 3 | kargasok
# Processing Record 1 of Set 4 | taltal
# Processing Record 2 of Set 4 | paracuru
# Processing Record 3 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 4 | soure
# Processing Record 5 of Set 4 | farafangana
# Processing Record 6 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 7 of Set 4 | dingle
# Processing Record 8 of Set 4 | loandjili
# Processing Record 9 of Set 4 | arraial do cabo
# Processing Record 10 of Set 4 | ust-tsilma
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | vila franca do campo
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | marawi
# Processing Record 15 of Set 4 | manjacaze
# Processing Record 16 of Set 4 | sandwick
# Processing Record 17 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 18 of Set 4 | sorland
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | aksu
# Processing Record 21 of Set 4 | jalu
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | punta arenas
# Processing Record 24 of Set 4 | sur
# Processing Record 25 of Set 4 | victoria
# Processing Record 26 of Set 4 | bajil
# Processing Record 27 of Set 4 | rusape
# Processing Record 28 of Set 4 | bataipora
# Processing Record 29 of Set 4 | ambilobe
# Processing Record 30 of Set 4 | qasigiannguit
# Processing Record 31 of Set 4 | manaus
# Processing Record 32 of Set 4 | rognan
# Processing Record 33 of Set 4 | buchanan
# Processing Record 34 of Set 4 | bouca
# Processing Record 35 of Set 4 | nikel
# Processing Record 36 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 4 | sisimiut
# Processing Record 38 of Set 4 | nantucket
# Processing Record 39 of Set 4 | asfi
# Processing Record 40 of Set 4 | derzhavinsk
# Processing Record 41 of Set 4 | huarmey
# Processing Record 42 of Set 4 | kavali
# Processing Record 43 of Set 4 | vestmannaeyjar
# Processing Record 44 of Set 4 | corrente
# Processing Record 45 of Set 4 | oum hadjer
# Processing Record 46 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 4 | san felipe
# Processing Record 48 of Set 4 | divnomorskoye
# Processing Record 49 of Set 4 | charlestown
# Processing Record 50 of Set 4 | sao borja
# Processing Record 1 of Set 5 | state college
# Processing Record 2 of Set 5 | faya
# Processing Record 3 of Set 5 | harindanga
# Processing Record 4 of Set 5 | khash
# Processing Record 5 of Set 5 | leningradskiy
# Processing Record 6 of Set 5 | castro
# Processing Record 7 of Set 5 | usinsk
# Processing Record 8 of Set 5 | camacha
# Processing Record 9 of Set 5 | tazovskiy
# Processing Record 10 of Set 5 | abonnema
# Processing Record 11 of Set 5 | rio gallegos
# Processing Record 12 of Set 5 | beboto
# Processing Record 13 of Set 5 | salekhard
# Processing Record 14 of Set 5 | port-gentil
# Processing Record 15 of Set 5 | karibib
# Processing Record 16 of Set 5 | nauta
# Processing Record 17 of Set 5 | torva
# Processing Record 18 of Set 5 | marki
# Processing Record 19 of Set 5 | rio grande
# Processing Record 20 of Set 5 | yar-sale
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | kharitonovo
# Processing Record 23 of Set 5 | kalmunai
# Processing Record 24 of Set 5 | burgeo
# Processing Record 25 of Set 5 | warmbad
# Processing Record 26 of Set 5 | mercedes
# Processing Record 27 of Set 5 | kenitra
# Processing Record 28 of Set 5 | thompson
# Processing Record 29 of Set 5 | tanta
# Processing Record 30 of Set 5 | san jose
# Processing Record 31 of Set 5 | muros
# Processing Record 32 of Set 5 | fjerritslev
# Processing Record 33 of Set 5 | ponezhukay
# Processing Record 34 of Set 5 | ouadda
# Processing Record 35 of Set 5 | san luis
# Processing Record 36 of Set 5 | sinnamary
# Processing Record 37 of Set 5 | the valley
# Processing Record 38 of Set 5 | aksay
# Processing Record 39 of Set 5 | atar
# Processing Record 40 of Set 5 | moldava nad bodvou
# Processing Record 41 of Set 5 | la maddalena
# Processing Record 42 of Set 5 | warrington
# Processing Record 43 of Set 5 | bueno brandao
# Processing Record 44 of Set 5 | saint-georges
# Processing Record 45 of Set 5 | sao joao da barra
# Processing Record 46 of Set 5 | simi
# Processing Record 47 of Set 5 | arrecife
# Processing Record 48 of Set 5 | tala
# Processing Record 49 of Set 5 | goias
# Processing Record 50 of Set 5 | caravelas
# Processing Record 1 of Set 6 | pedasi
# Processing Record 2 of Set 6 | newark
# Processing Record 3 of Set 6 | chapais
# Processing Record 4 of Set 6 | balad
# Processing Record 5 of Set 6 | acarau
# Processing Record 6 of Set 6 | clyde river
# Processing Record 7 of Set 6 | inta
# Processing Record 8 of Set 6 | bangassou
# Processing Record 9 of Set 6 | nahrin
# Processing Record 10 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 11 of Set 6 | dorfen
# Processing Record 12 of Set 6 | sebeta
# Processing Record 13 of Set 6 | atocha
# Processing Record 14 of Set 6 | ekibastuz
# Processing Record 15 of Set 6 | nushki
# Processing Record 16 of Set 6 | bani
# Processing Record 17 of Set 6 | talnakh
# Processing Record 18 of Set 6 | krasnoye
# Processing Record 19 of Set 6 | pakhtakoron
# Processing Record 20 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 6 | namibe
# Processing Record 22 of Set 6 | carutapera
# Processing Record 23 of Set 6 | banda aceh
# Processing Record 24 of Set 6 | shepsi
# Processing Record 25 of Set 6 | saint-francois
# Processing Record 26 of Set 6 | abu kamal
# Processing Record 27 of Set 6 | mabaruma
# Processing Record 28 of Set 6 | entebbe
# Processing Record 29 of Set 6 | ambanja
# Processing Record 30 of Set 6 | villazon
# Processing Record 31 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 32 of Set 6 | sinop
# Processing Record 33 of Set 6 | quatre cocos
# Processing Record 34 of Set 6 | san antonio
# Processing Record 35 of Set 6 | lubao
# Processing Record 36 of Set 6 | broadford
# Processing Record 37 of Set 6 | san carlos de bariloche
# Processing Record 38 of Set 6 | bonthe
# Processing Record 39 of Set 6 | grand gaube
# Processing Record 40 of Set 6 | illapel
# Processing Record 41 of Set 6 | kovdor
# Processing Record 42 of Set 6 | san ramon
# Processing Record 43 of Set 6 | camapua
# Processing Record 44 of Set 6 | wamba
# Processing Record 45 of Set 6 | riohacha
# Processing Record 46 of Set 6 | a
# City not found. Skipping...
# Processing Record 47 of Set 6 | washington
# Processing Record 48 of Set 6 | quepos
# Processing Record 49 of Set 6 | andenes
# Processing Record 50 of Set 6 | saint-pierre
# Processing Record 1 of Set 7 | saint anthony
# Processing Record 2 of Set 7 | anloga
# Processing Record 3 of Set 7 | boueni
# Processing Record 4 of Set 7 | safakulevo
# Processing Record 5 of Set 7 | dasoguz
# Processing Record 6 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 7 of Set 7 | satinka
# Processing Record 8 of Set 7 | ilulissat
# Processing Record 9 of Set 7 | hun
# Processing Record 10 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 7 | ghatampur
# Processing Record 12 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 7 | sabha
# Processing Record 14 of Set 7 | sao filipe
# Processing Record 15 of Set 7 | resistencia
# Processing Record 16 of Set 7 | nikolskiy
# Processing Record 17 of Set 7 | kapoeta
# Processing Record 18 of Set 7 | kokstad
# Processing Record 19 of Set 7 | saint-joseph
# Processing Record 20 of Set 7 | wittingen
# Processing Record 21 of Set 7 | puerto del rosario
# Processing Record 22 of Set 7 | port blair
# Processing Record 23 of Set 7 | itubera
# Processing Record 24 of Set 7 | esik
# Processing Record 25 of Set 7 | geraldton
# Processing Record 26 of Set 7 | unirea
# Processing Record 27 of Set 7 | itarema
# Processing Record 28 of Set 7 | suda
# Processing Record 29 of Set 7 | jutai
# Processing Record 30 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 7 | petrosani
# Processing Record 32 of Set 7 | mogadishu
# Processing Record 33 of Set 7 | san juan
# Processing Record 34 of Set 7 | bajna
# Processing Record 35 of Set 7 | tarko-sale
# Processing Record 36 of Set 7 | prestea
# Processing Record 37 of Set 7 | santa isabel do rio negro
# Processing Record 38 of Set 7 | vamdrup
# Processing Record 39 of Set 7 | zhelyabovka
# Processing Record 40 of Set 7 | villa carlos paz
# Processing Record 41 of Set 7 | zyryanovsk
# Processing Record 42 of Set 7 | mantua
# Processing Record 43 of Set 7 | cayenne
# Processing Record 44 of Set 7 | serebryansk
# Processing Record 45 of Set 7 | shelburne
# Processing Record 46 of Set 7 | ponta delgada
# Processing Record 47 of Set 7 | hambantota
# Processing Record 48 of Set 7 | olafsvik
# Processing Record 49 of Set 7 | yarim
# Processing Record 50 of Set 7 | consett
# Processing Record 1 of Set 8 | mahibadhoo
# Processing Record 2 of Set 8 | husavik
# Processing Record 3 of Set 8 | ust-kulom
# Processing Record 4 of Set 8 | pauini
# Processing Record 5 of Set 8 | sokolo
# Processing Record 6 of Set 8 | marfino
# Processing Record 7 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 8 | tamsalu
# Processing Record 9 of Set 8 | natal
# Processing Record 10 of Set 8 | barra dos coqueiros
# Processing Record 11 of Set 8 | spencer
# Processing Record 12 of Set 8 | wukari
# Processing Record 13 of Set 8 | corn island
# Processing Record 14 of Set 8 | narsipatnam
# Processing Record 15 of Set 8 | ronneby
# Processing Record 16 of Set 8 | solginskiy
# Processing Record 17 of Set 8 | rorvik
# Processing Record 18 of Set 8 | rawson
# Processing Record 19 of Set 8 | badnawar
# Processing Record 20 of Set 8 | codrington
# Processing Record 21 of Set 8 | krasnoselkup
# Processing Record 22 of Set 8 | oudtshoorn
# Processing Record 23 of Set 8 | saint-augustin
# Processing Record 24 of Set 8 | sao luis do quitunde
# Processing Record 25 of Set 8 | doume
# Processing Record 26 of Set 8 | la gloria
# Processing Record 27 of Set 8 | dzaoudzi
# Processing Record 28 of Set 8 | shadegan
# Processing Record 29 of Set 8 | copiapo
# Processing Record 30 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 8 | belyy yar
# Processing Record 32 of Set 8 | temir
# Processing Record 33 of Set 8 | issenye
# Processing Record 34 of Set 8 | hobyo
# Processing Record 35 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 36 of Set 8 | buraydah
# Processing Record 37 of Set 8 | takoradi
# Processing Record 38 of Set 8 | izhma
# Processing Record 39 of Set 8 | suluq
# Processing Record 40 of Set 8 | laguna
# Processing Record 41 of Set 8 | rajshahi
# Processing Record 42 of Set 8 | marsh harbour
# Processing Record 43 of Set 8 | kosa
# Processing Record 44 of Set 8 | miass
# Processing Record 45 of Set 8 | uvat
# Processing Record 46 of Set 8 | mao
# Processing Record 47 of Set 8 | porto novo
# Processing Record 48 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 8 | lima
# Processing Record 50 of Set 8 | maine-soroa
# Processing Record 1 of Set 9 | harer
# Processing Record 2 of Set 9 | medina del campo
# Processing Record 3 of Set 9 | soyo
# Processing Record 4 of Set 9 | mahanoro
# Processing Record 5 of Set 9 | opuwo
# Processing Record 6 of Set 9 | santa rosa
# Processing Record 7 of Set 9 | ivankiv
# Processing Record 8 of Set 9 | swinford
# Processing Record 9 of Set 9 | olinda
# Processing Record 10 of Set 9 | mandera
# Processing Record 11 of Set 9 | cabedelo
# Processing Record 12 of Set 9 | nouadhibou
# Processing Record 13 of Set 9 | padang
# Processing Record 14 of Set 9 | pozo colorado
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | fougamou
# Processing Record 17 of Set 9 | hualmay
# Processing Record 18 of Set 9 | bubaque
# Processing Record 19 of Set 9 | cusuna
# Processing Record 20 of Set 9 | astana
# Processing Record 21 of Set 9 | dalvik
# Processing Record 22 of Set 9 | middelburg
# Processing Record 23 of Set 9 | goundam
# Processing Record 24 of Set 9 | spassk
# Processing Record 25 of Set 9 | okakarara
# Processing Record 26 of Set 9 | rabo de peixe
# Processing Record 27 of Set 9 | ouallam
# Processing Record 28 of Set 9 | marzuq
# Processing Record 29 of Set 9 | makokou
# Processing Record 30 of Set 9 | henties bay
# Processing Record 31 of Set 9 | bilma
# Processing Record 32 of Set 9 | road town
# Processing Record 33 of Set 9 | mecca
# Processing Record 34 of Set 9 | roccastrada
# Processing Record 35 of Set 9 | sydney mines
# Processing Record 36 of Set 9 | marquette
# Processing Record 37 of Set 9 | zaykovo
# Processing Record 38 of Set 9 | santa maria
# Processing Record 39 of Set 9 | obo
# Processing Record 40 of Set 9 | vytegra
# Processing Record 41 of Set 9 | gamba
# Processing Record 42 of Set 9 | conceicao do araguaia
# Processing Record 43 of Set 9 | pocosol
# Processing Record 44 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 45 of Set 9 | jaicos
# Processing Record 46 of Set 9 | paamiut
# Processing Record 47 of Set 9 | lukulu
# Processing Record 48 of Set 9 | remanso
# Processing Record 49 of Set 9 | cockburn town
# Processing Record 50 of Set 9 | garbsen
# Processing Record 1 of Set 10 | xai-xai
# Processing Record 2 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 10 | el alto
# Processing Record 4 of Set 10 | yining
# Processing Record 5 of Set 10 | batyrevo
# Processing Record 6 of Set 10 | bar harbor
# Processing Record 7 of Set 10 | channel-port aux basques
# Processing Record 8 of Set 10 | marsa matruh
# Processing Record 9 of Set 10 | bay roberts
# Processing Record 10 of Set 10 | amargosa
# Processing Record 11 of Set 10 | strezhevoy
# Processing Record 12 of Set 10 | owerri
# Processing Record 13 of Set 10 | schruns
# Processing Record 14 of Set 10 | srebrenik
# Processing Record 15 of Set 10 | clevelandia
# Processing Record 16 of Set 10 | ornskoldsvik
# Processing Record 17 of Set 10 | los llanos de aridane
# Processing Record 18 of Set 10 | zaysan
# Processing Record 19 of Set 10 | skjervoy
# Processing Record 20 of Set 10 | meulaboh
# Processing Record 21 of Set 10 | scarborough
# Processing Record 22 of Set 10 | calama
# Processing Record 23 of Set 10 | isilkul
# Processing Record 24 of Set 10 | angra
# City not found. Skipping...
# Processing Record 25 of Set 10 | misasi
# Processing Record 26 of Set 10 | tabuny
# Processing Record 27 of Set 10 | vangaindrano
# Processing Record 28 of Set 10 | pitimbu
# Processing Record 29 of Set 10 | mbandaka
# Processing Record 30 of Set 10 | brigantine
# Processing Record 31 of Set 10 | leshukonskoye
# Processing Record 32 of Set 10 | mozarlandia
# Processing Record 33 of Set 10 | severnoye
# Processing Record 34 of Set 10 | rockland
# Processing Record 35 of Set 10 | howell
# Processing Record 36 of Set 10 | galle
# Processing Record 37 of Set 10 | ambovombe
# Processing Record 38 of Set 10 | nampula
# Processing Record 39 of Set 10 | manbij
# Processing Record 40 of Set 10 | mapiripan
# Processing Record 41 of Set 10 | shushtar
# Processing Record 42 of Set 10 | santiago del estero
# Processing Record 43 of Set 10 | carupano
# Processing Record 44 of Set 10 | klaksvik
# Processing Record 45 of Set 10 | trindade
# Processing Record 46 of Set 10 | trapani
# Processing Record 47 of Set 10 | ntcheu
# Processing Record 48 of Set 10 | elmira
# Processing Record 49 of Set 10 | clarence town
# Processing Record 50 of Set 10 | ndele
# Processing Record 1 of Set 11 | sarahan
# Processing Record 2 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 3 of Set 11 | semey
# Processing Record 4 of Set 11 | itabira
# Processing Record 5 of Set 11 | akdepe
# Processing Record 6 of Set 11 | santa cruz de la palma
# Processing Record 7 of Set 11 | mezen
# Processing Record 8 of Set 11 | huanuni
# Processing Record 9 of Set 11 | conakry
# Processing Record 10 of Set 11 | tigzirt
# Processing Record 11 of Set 11 | kouroussa
# Processing Record 12 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 11 | miraflores
# Processing Record 14 of Set 11 | fort portal
# Processing Record 15 of Set 11 | grobina
# Processing Record 16 of Set 11 | beloha
# Processing Record 17 of Set 11 | shache
# Processing Record 18 of Set 11 | tiznit
# Processing Record 19 of Set 11 | bella union
# Processing Record 20 of Set 11 | garissa
# Processing Record 21 of Set 11 | lusambo
# Processing Record 22 of Set 11 | sann
# Processing Record 23 of Set 11 | dzyhivka
# Processing Record 24 of Set 11 | karasburg
# Processing Record 25 of Set 11 | itupiranga
# Processing Record 26 of Set 11 | dolany
# Processing Record 27 of Set 11 | vage
# Processing Record 28 of Set 11 | qaqortoq
# Processing Record 29 of Set 11 | bengkulu
# Processing Record 30 of Set 11 | phalaborwa
# Processing Record 31 of Set 11 | bahir dar
# Processing Record 32 of Set 11 | ceres
# Processing Record 33 of Set 11 | pogar
# Processing Record 34 of Set 11 | vondrozo
# Processing Record 35 of Set 11 | muromtsevo
# Processing Record 36 of Set 11 | ulagan
# Processing Record 37 of Set 11 | maseru
# Processing Record 38 of Set 11 | barcelos
# Processing Record 39 of Set 11 | athens
# Processing Record 40 of Set 11 | puerto ayacucho
# Processing Record 41 of Set 11 | dudinka
# Processing Record 42 of Set 11 | matagami
# Processing Record 43 of Set 11 | hanumangarh
# Processing Record 44 of Set 11 | yei
# Processing Record 45 of Set 11 | mbulu
# Processing Record 46 of Set 11 | la asuncion
# Processing Record 47 of Set 11 | kailaras
# Processing Record 48 of Set 11 | blonduos
# City not found. Skipping...
# Processing Record 49 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 11 | amapa
# Processing Record 1 of Set 12 | klaipeda
# Processing Record 2 of Set 12 | tessalit
# Processing Record 3 of Set 12 | kamenka
# Processing Record 4 of Set 12 | orje
# Processing Record 5 of Set 12 | ustynivka
# Processing Record 6 of Set 12 | tres lagoas
# Processing Record 7 of Set 12 | rio branco
# Processing Record 8 of Set 12 | antofagasta
# Processing Record 9 of Set 12 | cotonou
# Processing Record 10 of Set 12 | bulaevo
# Processing Record 11 of Set 12 | koroni
# Processing Record 12 of Set 12 | jumla
# Processing Record 13 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 14 of Set 12 | aksarka
# Processing Record 15 of Set 12 | pleshanovo
# Processing Record 16 of Set 12 | santa cruz
# Processing Record 17 of Set 12 | bergerac
# Processing Record 18 of Set 12 | kambove
# Processing Record 19 of Set 12 | boa vista
# Processing Record 20 of Set 12 | awbari
# Processing Record 21 of Set 12 | puerto suarez
# Processing Record 22 of Set 12 | gambela
# Processing Record 23 of Set 12 | camacari
# Processing Record 24 of Set 12 | yashkul
# Processing Record 25 of Set 12 | ibra
# Processing Record 26 of Set 12 | bria
# Processing Record 27 of Set 12 | lonar
# Processing Record 28 of Set 12 | dickson
# Processing Record 29 of Set 12 | bolobo
# Processing Record 30 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 31 of Set 12 | shugurovo
# Processing Record 32 of Set 12 | cleethorpes
# Processing Record 33 of Set 12 | novoagansk
# Processing Record 34 of Set 12 | hvolsvollur
# Processing Record 35 of Set 12 | porto santo
# Processing Record 36 of Set 12 | puerto carreno
# Processing Record 37 of Set 12 | asyut
# Processing Record 38 of Set 12 | grand baie
# Processing Record 39 of Set 12 | virginia beach
# Processing Record 40 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 12 | arlit
# Processing Record 42 of Set 12 | abu dhabi
# Processing Record 43 of Set 12 | sokoto
# Processing Record 44 of Set 12 | colares
# Processing Record 45 of Set 12 | praia da vitoria
# Processing Record 46 of Set 12 | axim
# Processing Record 47 of Set 12 | manaure
# Processing Record 48 of Set 12 | nola
# Processing Record 49 of Set 12 | manali
# Processing Record 50 of Set 12 | entre rios
# Processing Record 1 of Set 13 | artigas
# Processing Record 2 of Set 13 | bokoro
# Processing Record 3 of Set 13 | trelew
# Processing Record 4 of Set 13 | kobojango
# City not found. Skipping...
# Processing Record 5 of Set 13 | mirebalais
# Processing Record 6 of Set 13 | orebro
# Processing Record 7 of Set 13 | patacamaya
# Processing Record 8 of Set 13 | ballina
# Processing Record 9 of Set 13 | xuddur
# Processing Record 10 of Set 13 | ylivieska
# Processing Record 11 of Set 13 | sumbe
# Processing Record 12 of Set 13 | camopi
# Processing Record 13 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 14 of Set 13 | ilinskiy
# Processing Record 15 of Set 13 | yauya
# Processing Record 16 of Set 13 | cassilandia
# Processing Record 17 of Set 13 | kamareddi
# Processing Record 18 of Set 13 | qeshm
# Processing Record 19 of Set 13 | torres
# Processing Record 20 of Set 13 | krasnyy tekstilshchik
# City not found. Skipping...
# Processing Record 21 of Set 13 | calvinia
# Processing Record 22 of Set 13 | iturama
# Processing Record 23 of Set 13 | moose factory
# Processing Record 24 of Set 13 | dabakala
# Processing Record 25 of Set 13 | orocue
# Processing Record 26 of Set 13 | vestmanna
# Processing Record 27 of Set 13 | katesh
# Processing Record 28 of Set 13 | olden
# Processing Record 29 of Set 13 | bafoulabe
# Processing Record 30 of Set 13 | hit
# Processing Record 31 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 33 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 13 | iquique
# Processing Record 35 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 36 of Set 13 | nizwa
# Processing Record 37 of Set 13 | storebo
# Processing Record 38 of Set 13 | port-de-paix
# City not found. Skipping...
# Processing Record 39 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 40 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 41 of Set 13 | barbacoas
# Processing Record 42 of Set 13 | andijon
# Processing Record 43 of Set 13 | sao felix do xingu
# Processing Record 44 of Set 13 | tucupita
# Processing Record 45 of Set 13 | firminy
# Processing Record 46 of Set 13 | grand haven
# Processing Record 47 of Set 13 | cayeli
# Processing Record 48 of Set 13 | belaya glina
# Processing Record 49 of Set 13 | khairpur nathan shah
# Processing Record 50 of Set 13 | shubarkuduk
# Processing Record 1 of Set 14 | halkirk
# Processing Record 2 of Set 14 | port hawkesbury
# Processing Record 3 of Set 14 | malindi
# Processing Record 4 of Set 14 | novomykolayivka
# Processing Record 5 of Set 14 | sovetskiy
# Processing Record 6 of Set 14 | sioux lookout
# Processing Record 7 of Set 14 | lamu
# Processing Record 8 of Set 14 | leh
# Processing Record 9 of Set 14 | elin pelin
# Processing Record 10 of Set 14 | mbengwi
# Processing Record 11 of Set 14 | blackwood
# Processing Record 12 of Set 14 | old town
# Processing Record 13 of Set 14 | raudeberg
# Processing Record 14 of Set 14 | sao jose da coroa grande
# Processing Record 15 of Set 14 | birin
# Processing Record 16 of Set 14 | inhambane
# Processing Record 17 of Set 14 | alto araguaia
# Processing Record 18 of Set 14 | matara
# Processing Record 19 of Set 14 | pontes e lacerda
# Processing Record 20 of Set 14 | kilosa
# Processing Record 21 of Set 14 | boras
# Processing Record 22 of Set 14 | jacareacanga
# Processing Record 23 of Set 14 | ajaccio
# Processing Record 24 of Set 14 | rurrenabaque
# Processing Record 25 of Set 14 | mahon
# Processing Record 26 of Set 14 | kondinskoye
# Processing Record 27 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 29 of Set 14 | bud
# Processing Record 30 of Set 14 | aranos
# Processing Record 31 of Set 14 | troitskoye
# Processing Record 32 of Set 14 | santa marta
# Processing Record 33 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 14 | sechura
# Processing Record 35 of Set 14 | albany
# Processing Record 36 of Set 14 | aras
# Processing Record 37 of Set 14 | sao miguel do araguaia
# Processing Record 38 of Set 14 | laon
# Processing Record 39 of Set 14 | mananara
# Processing Record 40 of Set 14 | north myrtle beach
# Processing Record 41 of Set 14 | villa sandino
# Processing Record 42 of Set 14 | san francisco
# Processing Record 43 of Set 14 | sirvintos
# Processing Record 44 of Set 14 | kanniyakumari
# Processing Record 45 of Set 14 | makinsk
# Processing Record 46 of Set 14 | mmabatho
# Processing Record 47 of Set 14 | kabo
# Processing Record 48 of Set 14 | monrovia
# Processing Record 49 of Set 14 | misratah
# Processing Record 50 of Set 14 | belmonte
# Processing Record 1 of Set 15 | bogorodskoye
# Processing Record 2 of Set 15 | leo
# Processing Record 3 of Set 15 | malavalli
# Processing Record 4 of Set 15 | neustrelitz
# Processing Record 5 of Set 15 | bolu
# Processing Record 6 of Set 15 | dwarka
# Processing Record 7 of Set 15 | viedma
# Processing Record 8 of Set 15 | morristown
# Processing Record 9 of Set 15 | navrongo
# Processing Record 10 of Set 15 | ullapool
# Processing Record 11 of Set 15 | reserva
# Processing Record 12 of Set 15 | dakar
# Processing Record 13 of Set 15 | nadym
# Processing Record 14 of Set 15 | alta floresta
# Processing Record 15 of Set 15 | barkly west
# Processing Record 16 of Set 15 | mahanje
# Processing Record 17 of Set 15 | dinguiraye
# Processing Record 18 of Set 15 | abnub
# Processing Record 19 of Set 15 | oranjestad
# Processing Record 20 of Set 15 | kyshtovka
# Processing Record 21 of Set 15 | saurimo
# Processing Record 22 of Set 15 | stromness
# Processing Record 23 of Set 15 | doka
# Processing Record 24 of Set 15 | ikongo
# Processing Record 25 of Set 15 | morondava
# Processing Record 26 of Set 15 | lubango
# Processing Record 27 of Set 15 | umm lajj
# Processing Record 28 of Set 15 | saint augustine
# Processing Record 29 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 30 of Set 15 | itiuba
# Processing Record 31 of Set 15 | port-cartier
# Processing Record 32 of Set 15 | florianopolis
# Processing Record 33 of Set 15 | krasnoborsk
# Processing Record 34 of Set 15 | gurupi
# Processing Record 35 of Set 15 | valparaiso
# Processing Record 36 of Set 15 | abengourou
# Processing Record 37 of Set 15 | rakhya
# City not found. Skipping...
# Processing Record 38 of Set 15 | goya
# Processing Record 39 of Set 15 | anjozorobe
# Processing Record 40 of Set 15 | bronnoysund
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 687

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Maragogi  -9.0122 -35.2225     76.95        83          74
# 1     Port Alfred -33.5906  26.8910     63.18        94         100
# 2        Zaozerne  45.1582  33.2787     54.37        82         100
# 3           Turek  52.0155  18.5005     30.61        77           7
# 4  Saint-Philippe -21.3585  55.7679     69.39        71          37
# 5    Kruisfontein -34.0033  24.7314     61.88        69         100
# 6           Rafai   4.9500  23.9167     69.19        83           9
# 7       Thinadhoo   0.5333  72.9333     81.09        74          84
# 8           Jizan  17.3333  42.6667     79.74        67           0
# 9          Ghanzi -21.5667  21.7833     79.66        25           0
#
#    Wind Speed Country       Weather Dsc
# 0        8.41      BR     broken clouds
# 1        6.60      ZA   overcast clouds
# 2       24.56      UA   overcast clouds
# 3        7.00      PL         clear sky
# 4        6.58      RE  scattered clouds
# 5        2.35      ZA   overcast clouds
# 6        2.08      CF         clear sky
# 7       13.71      MV     broken clouds
# 8        2.62      SA         clear sky
# 9        8.21      BW         clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Dsc'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reorder_column_list=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Dsc"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[reorder_column_list]

# Display sample data
city_data_df.head()
# Out:
#              City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Maragogi      BR  -9.0122 -35.2225     76.95        83          74
# 1     Port Alfred      ZA -33.5906  26.8910     63.18        94         100
# 2        Zaozerne      UA  45.1582  33.2787     54.37        82         100
# 3           Turek      PL  52.0155  18.5005     30.61        77           7
# 4  Saint-Philippe      RE -21.3585  55.7679     69.39        71          37
#
#    Wind Speed       Weather Dsc
# 0        8.41     broken clouds
# 1        6.60   overcast clouds
# 2       24.56   overcast clouds
# 3        7.00         clear sky
# 4        6.58  scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Weather Dsc     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_name="WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_name,index_label="City_ID")
